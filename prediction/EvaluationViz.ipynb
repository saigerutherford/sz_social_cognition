# %%
import pandas as pd
import numpy as np
import pickle
from matplotlib import pyplot as plt
import operator

# %%
emsup_r = np.load('ep_bbs_test_r_arr_emsup.npy')
emsup_ev = np.load('ep_bbs_test_ev_arr_emsup.npy')
emsup_mse = np.load('ep_bbs_test_mse_arr_emsup.npy')
emsup_r_perm = np.load('ep_bbs_test_r_arr_shuff_emsup.npy')
emsup_ev_perm = np.load('ep_bbs_test_ev_arr_shuff_emsup.npy')
emsup_mse_perm = np.load('ep_bbs_test_mse_arr_shuff_emsup.npy')

# %%
emsup_r_tr = np.load('ep_bbs_train_r_arr_emsup.npy')
emsup_ev_tr = np.load('ep_bbs_train_ev_arr_emsup.npy')
emsup_mse_tr = np.load('ep_bbs_train_mse_arr_emsup.npy')
emsup_r_perm_tr = np.load('ep_bbs_train_r_arr_shuff_emsup.npy')
emsup_ev_perm_tr = np.load('ep_bbs_train_ev_arr_shuff_emsup.npy')
emsup_mse_perm_tr = np.load('ep_bbs_train_mse_arr_shuff_emsup.npy')

# %%
friend_r = np.load('ep_bbs_test_r_arr_friend.npy')
friend_ev = np.load('ep_bbs_test_ev_arr_friend.npy')
friend_mse = np.load('ep_bbs_test_mse_arr_friend.npy')
friend_r_perm = np.load('ep_bbs_test_r_arr_shuff_friend.npy')
friend_ev_perm = np.load('ep_bbs_test_ev_arr_shuff_friend.npy')
friend_mse_perm = np.load('ep_bbs_test_mse_arr_shuff_friend.npy')

# %%
friend_r_tr = np.load('ep_bbs_train_r_arr_friend.npy')
friend_ev_tr = np.load('ep_bbs_train_ev_arr_friend.npy')
friend_mse_tr = np.load('ep_bbs_train_mse_arr_friend.npy')
friend_r_perm_tr = np.load('ep_bbs_train_r_arr_shuff_friend.npy')
friend_ev_perm_tr = np.load('ep_bbs_train_ev_arr_shuff_friend.npy')
friend_mse_perm_tr = np.load('ep_bbs_train_mse_arr_shuff_friend.npy')

# %%
peer_r = np.load('ep_bbs_test_r_arr_peer.npy')
peer_ev = np.load('ep_bbs_test_ev_arr_peer.npy')
peer_mse = np.load('ep_bbs_test_mse_arr_peer.npy')
peer_r_perm = np.load('ep_bbs_test_r_arr_shuff_peer.npy')
peer_ev_perm = np.load('ep_bbs_test_ev_arr_shuff_peer.npy')
peer_mse_perm = np.load('ep_bbs_test_mse_arr_shuff_peer.npy')

# %%
peer_r_tr = np.load('ep_bbs_train_r_arr_peer.npy')
peer_ev_tr = np.load('ep_bbs_train_ev_arr_peer.npy')
peer_mse_tr = np.load('ep_bbs_train_mse_arr_peer.npy')
peer_r_perm_tr = np.load('ep_bbs_train_r_arr_shuff_peer.npy')
peer_ev_perm_tr = np.load('ep_bbs_train_ev_arr_shuff_peer.npy')
peer_mse_perm_tr = np.load('ep_bbs_train_mse_arr_shuff_peer.npy')

# %%
gazewidth_r = np.load('sz_bbs_test_r_arr_gazewidth.npy')
gazewidth_ev = np.load('sz_bbs_test_ev_arr_gazewidth.npy')
gazewidth_mse = np.load('sz_bbs_test_mse_arr_gazewidth.npy')
gazewidth_r_perm = np.load('sz_bbs_test_r_arr_shuff_gazewidth.npy')
gazewidth_ev_perm = np.load('sz_bbs_test_ev_arr_shuff_gazewidth.npy')
gazewidth_mse_perm = np.load('sz_bbs_test_mse_arr_shuff_gazewidth.npy')

# %%
gazewidth_r_tr = np.load('sz_bbs_train_r_arr_gazewidth.npy')
gazewidth_ev_tr = np.load('sz_bbs_train_ev_arr_gazewidth.npy')
gazewidth_mse_tr = np.load('sz_bbs_train_mse_arr_gazewidth.npy')
gazewidth_r_perm_tr = np.load('sz_bbs_train_r_arr_shuff_gazewidth.npy')
gazewidth_ev_perm_tr = np.load('sz_bbs_train_ev_arr_shuff_gazewidth.npy')
gazewidth_mse_perm_tr = np.load('sz_bbs_train_mse_arr_shuff_gazewidth.npy')

# %%
msceit_r = np.load('sz_bbs_test_r_arr_msceit.npy')
msceit_ev = np.load('sz_bbs_test_ev_arr_msceit.npy')
msceit_mse = np.load('sz_bbs_test_mse_arr_msceit.npy')
msceit_r_perm = np.load('sz_bbs_test_r_arr_shuff_msceit.npy')
msceit_ev_perm = np.load('sz_bbs_test_ev_arr_shuff_msceit.npy')
msceit_mse_perm = np.load('sz_bbs_test_mse_arr_shuff_msceit.npy')

# %%
msceit_r_tr = np.load('sz_bbs_train_r_arr_msceit.npy')
msceit_ev_tr = np.load('sz_bbs_train_ev_arr_msceit.npy')
msceit_mse_tr = np.load('sz_bbs_train_mse_arr_msceit.npy')
msceit_r_perm_tr = np.load('sz_bbs_train_r_arr_shuff_msceit.npy')
msceit_ev_perm_tr = np.load('sz_bbs_train_ev_arr_shuff_msceit.npy')
msceit_mse_perm_tr = np.load('sz_bbs_train_mse_arr_shuff_msceit.npy')

# %%
result = plt.hist(emsup_r_perm[:,0], bins=20, edgecolor='k', alpha=0.5)

plt.axvline(0.19, linestyle='dashed', color='k', linewidth=2.5)
plt.axvline(0.40, linestyle='dashed', color='r', linewidth=2.5)


labels= ["Test", "Train",  "Perm"]
plt.legend(labels, fontsize=16)

plt.xlabel("Correlation", fontsize=20)  
plt.ylabel(" ", fontsize=18)
plt.xlim([-1.2,1.2])
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)
plt.title('Emotional Support', fontsize=24)
plt.savefig('EmotionalSupport_R.png',dpi=300, bbox_inches='tight')

# %%
result = plt.hist(emsup_ev_perm, bins=20, edgecolor='k', alpha=0.5)

plt.axvline(0.02, linestyle='dashed', color='k', linewidth=2.5)
plt.axvline(0.16, linestyle='dashed', color='r', linewidth=2.5)


labels= ["Test", "Train",  "Perm"]
plt.legend(labels, fontsize=16)

plt.xlabel("Explained Variance", fontsize=20)  
plt.ylabel(" ", fontsize=18)
plt.xlim([-1.2,1.2])
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)
plt.title('Emotional Support', fontsize=24)
plt.savefig('EmotionalSupport_EV.png',dpi=300, bbox_inches='tight')

# %%
result = plt.hist(emsup_mse_perm, bins=20, edgecolor='k', alpha=0.5)

plt.axvline(114, linestyle='dashed', color='k', linewidth=2.5)
plt.axvline(88, linestyle='dashed', color='r', linewidth=2.5)


labels= ["Test", "Train",  "Perm"]
plt.legend(labels, fontsize=16)

plt.xlabel("Mean Squared Error", fontsize=20)  
plt.ylabel(" ", fontsize=18)
#plt.xlim([-1.2,1.2])
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)
plt.title('Emotional Support', fontsize=24)
plt.savefig('EmotionalSupport_MSE.png',dpi=300, bbox_inches='tight')

# %%
result = plt.hist(friend_r_perm[:,0], bins=20, edgecolor='k', alpha=0.5)

plt.axvline(0.24, linestyle='dashed', color='k', linewidth=2.5)
plt.axvline(0.41, linestyle='dashed', color='r', linewidth=2.5)


labels= ["Test", "Train",  "Perm"]
plt.legend(labels, fontsize=16)

plt.xlabel("Correlation", fontsize=20)  
plt.ylabel(" ", fontsize=18)
plt.xlim([-1.2,1.2])
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)
plt.title('Friendship', fontsize=24)
plt.savefig('Friendship_R.png',dpi=300, bbox_inches='tight')

# %%
result = plt.hist(friend_ev_perm, bins=20, edgecolor='k', alpha=0.5)

plt.axvline(0.05, linestyle='dashed', color='k', linewidth=2.5)
plt.axvline(0.17, linestyle='dashed', color='r', linewidth=2.5)


labels= ["Test", "Train",  "Perm"]
plt.legend(labels, fontsize=16)

plt.xlabel("Explained Variance", fontsize=20)  
plt.ylabel(" ", fontsize=18)
plt.xlim([-1.2,1.2])
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)
plt.title('Friendship', fontsize=24)
plt.savefig('Friendship_EV.png',dpi=300, bbox_inches='tight')

# %%
result = plt.hist(friend_mse_perm, bins=20, edgecolor='k', alpha=0.5)

plt.axvline(129, linestyle='dashed', color='k', linewidth=2.5)
plt.axvline(101, linestyle='dashed', color='r', linewidth=2.5)


labels= ["Test", "Train",  "Perm"]
plt.legend(labels, fontsize=16)

plt.xlabel("Mean Squared Error", fontsize=20)  
plt.ylabel(" ", fontsize=18)
#plt.xlim([-1.2,1.2])
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)
plt.title('Friendship', fontsize=24)
plt.savefig('Friendship_MSE.png',dpi=300, bbox_inches='tight')

# %%
result = plt.hist(peer_r_perm[:,0], bins=20, edgecolor='k', alpha=0.5)

plt.axvline(0.17, linestyle='dashed', color='k', linewidth=2.5)
plt.axvline(0.39, linestyle='dashed', color='r', linewidth=2.5)


labels= ["Test", "Train",  "Perm"]
plt.legend(labels, fontsize=16)

plt.xlabel("Correlation", fontsize=20)  
plt.ylabel(" ", fontsize=18)
plt.xlim([-1.2,1.2])
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)
plt.title('Peer Rejection', fontsize=24)
plt.savefig('PeerRejection_R.png',dpi=300, bbox_inches='tight')

# %%
result = plt.hist(peer_ev_perm, bins=20, edgecolor='k', alpha=0.5)

plt.axvline(-0.03, linestyle='dashed', color='k', linewidth=2.5)
plt.axvline(0.16, linestyle='dashed', color='r', linewidth=2.5)


labels= ["Test", "Train",  "Perm"]
plt.legend(labels, fontsize=16)

plt.xlabel("Explained Variance", fontsize=20)  
plt.ylabel(" ", fontsize=18)
plt.xlim([-1.2,1.2])
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)
plt.title('Peer Rejection', fontsize=24)
plt.savefig('PeerRejection_EV.png',dpi=300, bbox_inches='tight')

# %%
result = plt.hist(peer_mse_perm, bins=20, edgecolor='k', alpha=0.5)

plt.axvline(135, linestyle='dashed', color='k', linewidth=2.5)
plt.axvline(107, linestyle='dashed', color='r', linewidth=2.5)


labels= ["Test", "Train",  "Perm"]
plt.legend(labels, fontsize=16)

plt.xlabel("Mean Squared Error", fontsize=20)  
plt.ylabel(" ", fontsize=18)
#plt.xlim([-1.2,1.2])
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)
plt.title('Peer Rejection', fontsize=24)
plt.savefig('PeerRejection_MSE.png',dpi=300, bbox_inches='tight')

# %%
result = plt.hist(msceit_r_perm[:,0], bins=20, edgecolor='k', alpha=0.5)

plt.axvline(-0.14, linestyle='dashed', color='k', linewidth=2.5)
plt.axvline(0.38, linestyle='dashed', color='r', linewidth=2.5)


labels= ["Test", "Train",  "Perm"]
plt.legend(labels, fontsize=16)

plt.xlabel("Correlation", fontsize=20)  
plt.ylabel(" ", fontsize=18)
plt.xlim([-1.2,1.2])
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)
plt.title('MSCEIT Total', fontsize=24)
plt.savefig('MSCEIT_R.png',dpi=300, bbox_inches='tight')

# %%
# remove gross outliers and implausible values
outlier_thresh = 3
yz_tr = (msceit_ev_perm - np.mean(msceit_ev_perm)) / np.std(msceit_ev_perm)
nz_tr = np.abs(yz_tr) < outlier_thresh
msceit_ev_perm2 = msceit_ev_perm[nz_tr]

# %%
result = plt.hist(msceit_ev_perm2, bins=20, edgecolor='k', alpha=0.5)

plt.axvline(-0.04, linestyle='dashed', color='k', linewidth=2.5)
plt.axvline(0.08, linestyle='dashed', color='r', linewidth=2.5)


labels= ["Test", "Train",  "Perm"]
plt.legend(labels, fontsize=16)

plt.xlabel("Explained Variance", fontsize=20)  
plt.ylabel(" ", fontsize=18)
plt.xlim([-2.5,1])
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)
plt.title('MSCEIT Total', fontsize=24)
plt.savefig('MSCEIT_EV.png',dpi=300, bbox_inches='tight')

# %%
# remove gross outliers and implausible values
outlier_thresh = 3
yz_tr = (msceit_mse_perm - np.mean(msceit_mse_perm)) / np.std(msceit_mse_perm)
nz_tr = np.abs(yz_tr) < outlier_thresh
msceit_mse_perm2 = msceit_mse_perm[nz_tr]

# %%
result = plt.hist(msceit_mse_perm2, bins=20, edgecolor='k', alpha=0.5)

plt.axvline(426, linestyle='dashed', color='k', linewidth=2.5)
plt.axvline(288, linestyle='dashed', color='r', linewidth=2.5)


labels= ["Test", "Train",  "Perm"]
plt.legend(labels, fontsize=16)

plt.xlabel("Mean Squared Error", fontsize=20)  
plt.ylabel(" ", fontsize=18)
plt.xlim([-0.1,1500])
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)
plt.title('MSCEIT Total', fontsize=24)
plt.savefig('MSCEIT_MSE.png',dpi=300, bbox_inches='tight')

# %%
result = plt.hist(gazewidth_r_perm[:,0], bins=20, edgecolor='k', alpha=0.5)

plt.axvline(0.61, linestyle='dashed', color='k', linewidth=2.5)
plt.axvline(0.77, linestyle='dashed', color='r', linewidth=2.5)


labels= ["Test", "Train",  "Perm"]
plt.legend(labels, fontsize=16)

plt.xlabel("Correlation", fontsize=20)  
plt.ylabel(" ", fontsize=18)
plt.xlim([-1.2,1.2])
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)
plt.title('Gaze Width', fontsize=24)
plt.savefig('GazeWidth_R.png',dpi=300, bbox_inches='tight')

# %%
# remove gross outliers and implausible values
outlier_thresh = 3
yz_tr = (gazewidth_ev_perm - np.mean(gazewidth_ev_perm)) / np.std(gazewidth_ev_perm)
nz_tr = np.abs(yz_tr) < outlier_thresh
gazewidth_ev_perm2 = gazewidth_ev_perm[nz_tr]

# %%
result = plt.hist(gazewidth_ev_perm2, bins=20, edgecolor='k', alpha=0.5)

plt.axvline(0.32, linestyle='dashed', color='k', linewidth=2.5)
plt.axvline(0.59, linestyle='dashed', color='r', linewidth=2.5)


labels= ["Test", "Train",  "Perm"]
plt.legend(labels, fontsize=16)

plt.xlabel("Explained Variance", fontsize=20)  
plt.ylabel(" ", fontsize=18)
plt.xlim([-2.5,1.2])
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)
plt.title('Gaze Width', fontsize=24)
plt.savefig('GazeWidth_EV.png',dpi=300, bbox_inches='tight')

# %%
# remove gross outliers and implausible values
outlier_thresh = 3
yz_tr = (gazewidth_mse_perm - np.mean(gazewidth_mse_perm)) / np.std(gazewidth_mse_perm)
nz_tr = np.abs(yz_tr) < outlier_thresh
gazewidth_mse_perm2 = gazewidth_mse_perm[nz_tr]

# %%
result = plt.hist(gazewidth_mse_perm2, bins=20, edgecolor='k', alpha=0.5)

plt.axvline(0.25, linestyle='dashed', color='k', linewidth=2.5)
plt.axvline(0.14, linestyle='dashed', color='r', linewidth=2.5)


labels= ["Test", "Train",  "Perm"]
plt.legend(labels, fontsize=16)

plt.xlabel("Mean Squared Error", fontsize=20)  
plt.ylabel(" ", fontsize=18)
plt.xlim([0,1.75])
plt.xticks(fontsize=16)  
plt.yticks(fontsize=16)
plt.title('GazeWidth', fontsize=24)
plt.savefig('GazeWidth_MSE.png',dpi=300, bbox_inches='tight')
